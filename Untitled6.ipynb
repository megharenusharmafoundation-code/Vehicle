# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.24.3

# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\infinity\appdata\roaming\python\python312\site-packages (3.0.0)
# Requirement already satisfied: openpyxl in c:\users\infinity\appdata\roaming\python\python312\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\infinity\appdata\roaming\python\python312\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\infinity\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\infinity\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in c:\users\infinity\appdata\roaming\python\python312\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\infinity\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("health_sensor.csv")

# %%
df.head()
# Out:
#    age  sleep_hours  work_hours  screen_time  water_intake  exercise  \
# 0   56     4.950843    9.799390     6.655425      2.396012         1
# 1   46     5.739277    6.050878     7.122773      1.500000         1
# 2   32     6.862036    9.726273     8.686619      1.741437         1
# 3   60     7.493963    7.585901     6.367793      3.281423         0
# 4   25     6.113116    5.780637     7.693597      2.589713         1
#
#    meals_per_day  caffeine_intake  social_interaction  heart_rate       spo2  \
# 0              2                1                   1   84.476567  97.013451
# 1              3                0                   1   76.988263  97.355122
# 2              2                1                   1   78.963376  96.336875
# 3              4                1                   1   86.397313  96.774124
# 4              3                0                   1   74.605210  97.610242
#
#    temperature  blood_pressure  cholesterol     glucose    insulin  \
# 0    36.889154      150.533171   225.867421  123.244423  28.554230
# 1    36.938951      153.188912   196.008205   95.401836  30.201545
# 2    36.808369      152.351626   197.222843  109.124052  28.255472
# 3    36.796904      143.764268   212.259231  106.022372  32.466890
# 4    36.423819      125.623723   181.037041   84.759179  17.951963
#
#    stress_level  mental_health_score  target
# 0      8.212414             4.511139       1
# 1      5.616521             6.370851       0
# 2      6.845342             4.345828       0
# 3      5.740141             5.073400       0
# 4      3.553031             9.313631       0

# %%
print("\nMissing values per column:\n", df.isna().sum())
# Out:
# Missing values per column:
#  age                    0
# sleep_hours            0
# work_hours             0
# screen_time            0
# water_intake           0
# exercise               0
# meals_per_day          0
# caffeine_intake        0
# social_interaction     0
# heart_rate             0
# spo2                   0
# temperature            0
# blood_pressure         0
# cholesterol            0
# glucose                0
# insulin                0
# stress_level           0
# mental_health_score    0
# target                 0
# dtype: int64

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\infinity\appdata\roaming\python\python312\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\infinity\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\infinity\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\infinity\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\infinity\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scikit-learn
print(scikit-learn.__version__)
# Out:
#   Cell In[23], line 1
#     import scikit-learn
#                  ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import LabelEncoder

encoders = {}
for col in ['exercise', 'caffeine_intake', 'target']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = dict(zip(le.classes_, le.transform(le.classes_)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.preprocessing import LabelEncoder
#       3 encoders = {}
#       4 for col in ['exercise', 'caffeine_intake', 'target']:
#
# ModuleNotFoundError: No module named 'sklearn'
